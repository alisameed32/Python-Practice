# %% [markdown]
# ![image.png](attachment:image.png)
#
# Hacker Rank: https://www.hackerrank.com/challenges/python-loops/problem?isFullScreen=true

# %%
n = int(input())
for i in range(n):
    print(i*i)
# Out:
# 0
# 1
# 4
